# %% [markdown]
# 1.write a program that creates a data frame from a dictionary of ndarrays and lists.

# %%
import numpy as np
import pandas as pd

# %%
data = {'cities':['dindigul','madurai','chennai'],'regnum':[57,58,27]} #{key:value}

# %%
dataframe = pd.DataFrame(data)

# %%
dataframe
# Out:
#      cities  regnum
# 0  dindigul      57
# 1   madurai      58
# 2   chennai      27

# %%
#2. write a program that creates a data frame storing names and marks of students using list of lists (nested list). give relevant name to the columns.

# %%
data2 = [['sasi',89],['amali',90],['dharini',92]]
df2 = pd.DataFrame(data2,columns = ['studname','marks'])
df2
# Out:
#   studname  marks
# 0     sasi     89
# 1    amali     90
# 2  dharini     92

# %% [markdown]
# 3. write a program to create a dataframe from a dictionary of series

# %%
data3 = {56 : pd.Series(['s','k','g']),57:pd.Series(['s','l','g'])}
df3 = pd.DataFrame(data3)

# %%
df3
# Out:
#   56 57
# 0  s  s
# 1  k  l
# 2  g  g

# %% [markdown]
# 4. write a program that selects a particular column from the dataframe also add a a new column

# %%
df3[57]
# Out:
# 0    s
# 1    l
# 2    g
# Name: 57, dtype: object

# %%
df3[60] = pd.Series(['j','k','s'])

# %%
df3
# Out:
#   57 60
# 0  s  j
# 1  l  k
# 2  g  s

# %%
df3.pop(56)
# Out:
# 0    s
# 1    k
# 2    g
# Name: 56, dtype: object

# %%
df3[1:2]
# Out:
#   57 60
# 1  l  k

# %% [markdown]
# head, tail,T,axes,dtypes,shape,size,values

# %%
print(df3.axes)
# Out:
# [RangeIndex(start=0, stop=3, step=1), Int64Index([57, 60], dtype='int64')]

# %%
unsorted_df = pd.DataFrame(np.random.randn(5,2),index = [3,4,2,5,1],columns =['a','b'])
unsorted_df
sorted_df = unsorted_df.sort_index()

# %%
sorted_df
# Out:
#           a         b
# 1  0.860384 -0.471937
# 2 -0.836961 -0.292809
# 3  0.292118 -1.745506
# 4 -0.661269 -1.411693
# 5 -2.079751 -0.400028

# %% [markdown]
# handling missing values
#
# null : nan
# zeros are not null

# %%
df4 = pd.DataFrame({1:pd.Series([5,6,7],index = ['a','b','c']), 2:pd.Series([7,8,9,4],index = ['a','b','c','d']),3:pd.Series([80,6],index = ['a','b'])})
df4.shape
# Out:
# (4, 3)

# %%
df4
# Out:
#      1  2     3
# a  5.0  7  80.0
# b  6.0  8   6.0
# c  7.0  9   NaN
# d  NaN  4   NaN

# %%
df4.isnull().sum()
# Out:
# 1    1
# 2    0
# 3    2
# dtype: int64

# %%
df4.dropna()
# Out:
#      1  2     3
# a  5.0  7  80.0
# b  6.0  8   6.0

# %%
#print(df4.add(df6,fill_value=0))

# %%
df4.fillna(6) # replacing null values
# Out:
#      1  2     3
# a  5.0  7  80.0
# b  6.0  8   6.0
# c  7.0  9   6.0
# d  6.0  4   6.0

# %%
df3
# Out:
#   57 60
# 0  s  j
# 1  l  k
# 2  g  s

# %%
df3.replace({'s':'yy'})
# Out:
#    57  60
# 0  yy   j
# 1   l   k
# 2   g  yy
